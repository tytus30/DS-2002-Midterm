# %% [markdown]
# ### Setting up this document

# %%
#importing libraries
import os
import numpy
import pandas as pd
from sqlalchemy import create_engine

# %%
#Declare & Assign Connection Variables for the MySQL Server & Databases with which You'll be Working 

host_name = "localhost"
host_ip = "127.0.0.1"
port = "3306"
user_id = "root"
pwd = "Suchottv20!"

src_dbname = "chinook"
dst_dbname = "chinook_dw"

# %%
# Define Functions for Getting Data From and Setting Data Into Databases

def get_dataframe(user_id, pwd, host_name, db_name, sql_query):
    conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}/{db_name}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    dframe = pd.read_sql(sql_query, connection);
    connection.close()
    
    return dframe


def set_dataframe(user_id, pwd, host_name, db_name, df, table_name, pk_column, db_operation):
    conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}/{db_name}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    
    if db_operation == "insert":
        df.to_sql(table_name, con=connection, index=False, if_exists='replace')
        sqlEngine.execute(f"ALTER TABLE {table_name} ADD PRIMARY KEY ({pk_column});")
            
    elif db_operation == "update":
        df.to_sql(table_name, con=connection, index=False, if_exists='append')
    
    connection.close()

# %%
# Create the New Data Warehouse database, and to Use it, Switch the Connection Context.

conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}"
sqlEngine = create_engine(conn_str, pool_recycle=3600)

sqlEngine.execute(f"DROP DATABASE IF EXISTS `{dst_dbname}`;")
sqlEngine.execute(f"CREATE DATABASE `{dst_dbname}`;")
sqlEngine.execute(f"USE {dst_dbname};")

# %% [markdown]
# ### Creating and populating the dimension tables

# %% [markdown]
# #### Extracting data from database

# %%
sql_customer = "SELECT * FROM chinook.customer;"
df_customer = get_dataframe(user_id, pwd, host_name, src_dbname, sql_customer)
df_customer.head(2)
# Out:
#    CustomerId FirstName   LastName  \
# 0           1      Luís  Gonçalves
# 1           2    Leonie     Köhler
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
#
#                            Address                 City State  Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP   Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None  Germany
#
#   PostalCode               Phone                 Fax                  Email  \
# 0  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566   luisg@embraer.com.br
# 1      70174    +49 0711 2842222                None  leonekohler@surfeu.de
#
#    SupportRepId
# 0             3
# 1             5

# %%
sql_employee = "SELECT * FROM chinook.employee;"
df_employee = get_dataframe(user_id, pwd, host_name, src_dbname, sql_employee)
df_employee.head(2)
# Out:
#    EmployeeId LastName FirstName            Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew  General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy    Sales Manager        1.0 1958-12-08
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
#
#                Phone                Fax                   Email
# 0  +1 (780) 428-9482  +1 (780) 428-3457  andrew@chinookcorp.com
# 1  +1 (403) 262-3443  +1 (403) 262-3322   nancy@chinookcorp.com

# %%
sql_track = "SELECT * FROM chinook.track;"
df_track = get_dataframe(user_id, pwd, host_name, src_dbname, sql_track)
df_track.head(2)
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
#
#    GenreId                                   Composer  Milliseconds     Bytes  \
# 0        1  Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1        1                                       None        342562   5510424
#
#    UnitPrice
# 0       0.99
# 1       0.99

# %%
sql_album = "SELECT * FROM chinook.album;"
df_album = get_dataframe(user_id, pwd, host_name, src_dbname, sql_album)
df_album.head(2)
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2

# %% [markdown]
# #### Performing transformations

# %%
drop_cols = ['Phone','Fax','Email','SupportRepId']
df_customer.drop(drop_cols, axis=1, inplace=True)
df_customer.rename(columns={"CustomerId":"customer_key"}, inplace=True)

df_customer.head(2)
# Out:
#    customer_key FirstName   LastName  \
# 0             1      Luís  Gonçalves
# 1             2    Leonie     Köhler
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
#
#                            Address                 City State  Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP   Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None  Germany
#
#   PostalCode
# 0  12227-000
# 1      70174

# %%
drop_cols = ['Phone','Fax','Email','ReportsTo']
df_employee.drop(drop_cols, axis=1, inplace=True)
df_employee.rename(columns={"EmployeeId":"employee_key"}, inplace=True)

df_employee.head(2)
# Out:
#    employee_key LastName FirstName            Title  BirthDate   HireDate  \
# 0             1    Adams    Andrew  General Manager 1962-02-18 2002-08-14
# 1             2  Edwards     Nancy    Sales Manager 1958-12-08 2002-05-01
#
#                Address      City State Country PostalCode
# 0  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3

# %%
drop_cols = ['Milliseconds','Bytes']
df_track.drop(drop_cols, axis=1, inplace=True)
df_track.rename(columns={"TrackId":"track_key"}, inplace=True)

df_track.head(2)
# Out:
#    track_key                                     Name  AlbumId  MediaTypeId  \
# 0          1  For Those About To Rock (We Salute You)        1            1
# 1          2                        Balls to the Wall        2            2
#
#    GenreId                                   Composer  UnitPrice
# 0        1  Angus Young, Malcolm Young, Brian Johnson       0.99
# 1        1                                       None       0.99

# %%
df_album.rename(columns={"AlbumId":"album_key"}, inplace=True)

df_album.head(2)
# Out:
#    album_key                                  Title  ArtistId
# 0          1  For Those About To Rock We Salute You         1
# 1          2                      Balls to the Wall         2

# %% [markdown]
# #### Load the Transformed DataFrames into the New Data Warehouse by Creating New Tables

# %%
db_operation = "insert"

tables = [('dim_customer', df_customer, 'customer_key'),
          ('dim_employee', df_employee, 'employee_key'),
          ('dim_track', df_track, 'track_key'),
          ('dim_album', df_album, 'album_key')]

# %%
for table_name, dataframe, primary_key in tables:
    set_dataframe(user_id, pwd, host_name, dst_dbname, dataframe, table_name, primary_key, db_operation)

# %% [markdown]
# ### Create and populate fact table

# %% [markdown]
# #### Getting data from all relavent tables

# %%
sql_invoice = "SELECT * FROM Chinook.invoice;"
df_invoice = get_dataframe(user_id, pwd, host_name, src_dbname, sql_invoice)
df_invoice.rename(columns={"InvoiceId":"invoice_id"}, inplace=True)
df_invoice.head(2)
# Out:
#    invoice_id  CustomerId InvoiceDate           BillingAddress BillingCity  \
# 0           1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart
# 1           2           4  2009-01-02         Ullevålsveien 14        Oslo
#
#   BillingState BillingCountry BillingPostalCode  Total
# 0         None        Germany             70174   1.98
# 1         None         Norway              0171   3.96

# %%
sql_invoiceline = "SELECT * FROM Chinook.invoiceline;"
df_invoiceline = get_dataframe(user_id, pwd, host_name, src_dbname, sql_invoiceline)
df_invoiceline.rename(columns={"InvoiceLineId":"invoiceline_id"}, inplace=True)
df_invoiceline.rename(columns={"InvoiceId":"invoice_id"}, inplace=True)
df_invoiceline.head(2)
# Out:
#    invoiceline_id  invoice_id  TrackId  UnitPrice  Quantity
# 0               1           1        2       0.99         1
# 1               2           1        4       0.99         1

# %% [markdown]
# #### Join the two above tables to create Fact Table.

# %%
df_invoice = pd.merge(df_invoice, df_invoiceline, on='invoice_id', how='right')
df_invoice.drop(['invoice_id'], axis=1, inplace=True)
df_invoice.head(4)
# Out:
#    CustomerId InvoiceDate           BillingAddress BillingCity BillingState  \
# 0           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart         None
# 1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart         None
# 2           4  2009-01-02         Ullevålsveien 14        Oslo         None
# 3           4  2009-01-02         Ullevålsveien 14        Oslo         None
#
#   BillingCountry BillingPostalCode  Total  invoiceline_id  TrackId  UnitPrice  \
# 0        Germany             70174   1.98               1        2       0.99
# 1        Germany             70174   1.98               2        4       0.99
# 2         Norway              0171   3.96               3        6       0.99
# 3         Norway              0171   3.96               4        8       0.99
#
#    Quantity
# 0         1
# 1         1
# 2         1
# 3         1

# %% [markdown]
# ##### Perform any Additional Transformations

# %%
# Insert a new column, with an ever-incrementing numeric value, to serve as the primary key.
df_invoice.insert(0, "order_key", range(1, df_invoice.shape[0]+1))
df_invoice.head(5)
# Out:
#    order_key  CustomerId InvoiceDate           BillingAddress BillingCity  \
# 0          1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart
# 1          2           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart
# 2          3           4  2009-01-02         Ullevålsveien 14        Oslo
# 3          4           4  2009-01-02         Ullevålsveien 14        Oslo
# 4          5           4  2009-01-02         Ullevålsveien 14        Oslo
#
#   BillingState BillingCountry BillingPostalCode  Total  invoiceline_id  \
# 0         None        Germany             70174   1.98               1
# 1         None        Germany             70174   1.98               2
# 2         None         Norway              0171   3.96               3
# 3         None         Norway              0171   3.96               4
# 4         None         Norway              0171   3.96               5
#
#    TrackId  UnitPrice  Quantity
# 0        2       0.99         1
# 1        4       0.99         1
# 2        6       0.99         1
# 3        8       0.99         1
# 4       10       0.99         1

# %% [markdown]
# ##### Write the DataFrame Back to the Database

# %%
table_name = "fact_invoice"
primary_key = "order_key"
db_operation = "insert"

set_dataframe(user_id, pwd, host_name, dst_dbname, df_invoice, table_name, primary_key, db_operation)

# %% [markdown]
# ### Demonstrate that the New Data Warehouse Exists and Contains the Correct Data

# %%
sql_test = """
    SELECT CustomerId AS `customer_id`,
        SUM(Quantity) AS `total_quantity`,
        SUM(UnitPrice) AS `total_unit_price`
    FROM `{0}`.`fact_invoice` AS invoice

    GROUP BY customer_id    
    ORDER BY total_unit_price DESC;
    
""".format(dst_dbname)

df_test = get_dataframe(user_id, pwd, host_name, src_dbname, sql_test)

# %%
df_test.head(100)
# Out:
#     customer_id  total_quantity  total_unit_price
# 0             6              38             49.62
# 1            26              38             47.62
# 2            57              38             46.62
# 3            46              38             45.62
# 4            45              38             45.62
# 5            37              38             43.62
# 6            24              38             43.62
# 7            28              38             43.62
# 8            25              38             42.62
# 9             7              38             42.62
# 10           44              38             41.62
# 11           48              38             40.62
# 12            5              38             40.62
# 13           43              38             40.62
# 14           34              38             39.62
# 15           20              38             39.62
# 16            4              38             39.62
# 17            3              38             39.62
# 18           42              38             39.62
# 19           17              38             39.62
# 20           22              38             39.62
# 21            1              38             39.62
# 22           40              38             38.62
# 23           51              38             38.62
# 24           15              38             38.62
# 25           19              38             38.62
# 26           39              38             38.62
# 27           58              38             38.62
# 28           13              38             37.62
# 29            2              38             37.62
# 30           50              38             37.62
# 31           53              38             37.62
# 32            8              38             37.62
# 33           29              38             37.62
# 34           30              38             37.62
# 35           32              38             37.62
# 36           14              38             37.62
# 37            9              38             37.62
# 38           11              38             37.62
# 39           47              38             37.62
# 40           49              38             37.62
# 41           23              38             37.62
# 42           38              38             37.62
# 43           52              38             37.62
# 44           16              38             37.62
# 45           21              38             37.62
# 46           31              38             37.62
# 47           54              38             37.62
# 48           55              38             37.62
# 49           10              38             37.62
# 50           27              38             37.62
# 51           33              38             37.62
# 52           41              38             37.62
# 53           18              38             37.62
# 54           36              38             37.62
# 55           56              38             37.62
# 56           12              38             37.62
# 57           35              38             37.62
# 58           59              36             36.64
